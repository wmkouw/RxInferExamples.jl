# %% [markdown]
# # ARxI agent: learn to drive

# %%
using RxInfer
using Plots

include("./distributions/mv_location_scale_t.jl")
include("./distributions/matrix_normal_wishart.jl")
include("./distributions/unboltzmann.jl")
include("./nodes/ARxI.jl")
include("./rules/ARxI/in.jl")
include("./rules/ARxI/out.jl")
include("./rules/ARxI/parameter.jl")
include("./src/helpers.jl")

include("./Robots.jl"); using Robots
